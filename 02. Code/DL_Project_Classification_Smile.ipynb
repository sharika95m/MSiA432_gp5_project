# %%
## Onetime run to unzip the images
#!unzip Dataset/img_align_celeba.zip -d Dataset/Raw > /dev/null

# %%
#Importing the needed packages
import numpy as np
import matplotlib.pyplot as plt
import skimage
from PIL import Image
from skimage import data, io, filters, color, exposure
from skimage.transform import rotate
import pandas as pd
import cv2
import glob
import time

# %matplotlib inline

# %% [markdown]
# # Data cleansing
#
# Below are the steps for data cleansing:
#
# 1. 50000 images are chosen for model training.
# 2. Extracting all images' pixel values to make features dataset
# 3. Extracting all images' labels to make labels

# %%
# Step 1 and 2
## Appending all images as an array
list_of_images = []
start_val = 1
stop_val = 50000

## Directory value may need to be changed
dir_val = 'Dataset/Raw/img_align_celeba/'

start = time.time()
for i in range(start_val,(stop_val + 1)): 
    curr_pic = str(i)
    curr_pic = ''.join(['0' for x in range(6-len(curr_pic))]) + curr_pic
    curr_pic = dir_val + curr_pic + ".jpg"
    training_set = np.array(Image.open(curr_pic))
    #training_set = cv2.imread(curr_pic)
    list_of_images.append(training_set)

    if(i%5000==0):
      print('Curr iteration is ' + str(i))

stop = time.time()

dataset = np.array(list_of_images)
print("The size of dataset: ", dataset.shape)
del list_of_images
# Out:
# Curr iteration is 5000
# Curr iteration is 10000
# Curr iteration is 15000
# Curr iteration is 20000
# Curr iteration is 25000
# Curr iteration is 30000
# Curr iteration is 35000
# Curr iteration is 40000
# Curr iteration is 45000
# Curr iteration is 50000
# The size of dataset:  (50000, 218, 178, 3)

# %%
# Step 3
## The attribute csv with all features
attributes_path = "Dataset/list_attr_celeba.csv"
attribute_df = pd.read_csv(attributes_path)
attribute_df = attribute_df.loc[:(stop_val -1 )]

#This will need to be changed with respect to attribute to train for
classification_attribute = "Smiling"

labels = np.where(attribute_df[classification_attribute]==1,1,0)
print("The size of labels: ", labels.shape)
# Out:
# The size of labels:  (50000,)

# %% [markdown]
# # Train-Test Split

# %%
## Choosing the first 30000 as the training set and the rest 20000 as the test set
x_train = dataset[:30000,:,:,:]
x_test = dataset[30000:,:,:,:]
del dataset

# %%
y_train = labels[:30000]
y_test = labels[30000:]
del labels

# %% [markdown]
# # Checking data and labels
#
# Label of 1 indicates that the attribute is present while 0 means it is absent.

# %%
# Display the first few  training images
images_and_labels = list(zip(x_train[:24], y_train[:24]))
plt.figure(figsize=(14,10))
for index, (image, label) in enumerate(images_and_labels):
    plt.subplot(4, 8, index + 1)
    plt.axis('off')
    plt.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')
    index = str(label)
    plt.title(index)
plt.show()

# %% [markdown]
# # Modeling
#
# In the modeling section, we will build a custom model, a transfer learning model and use a pre-trained model to check what can be detected on a few images.

# %%
# !pip install tensorflow-addons -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-addons in /nfs/home/kjs4242/.local/lib/python3.9/site-packages (0.16.1)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.20.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      |████████████████████████████████| 591 kB 28.4 MB/s
# Requirement already satisfied: packaging in /opt/tljh/user/lib/python3.9/site-packages (from tensorflow-addons) (21.3)
# Collecting typeguard<3.0.0,>=2.7
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/tljh/user/lib/python3.9/site-packages (from packaging->tensorflow-addons) (3.0.9)
# Installing collected packages: typeguard, tensorflow-addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.0.0
#     Uninstalling typeguard-4.0.0:
#       Successfully uninstalled typeguard-4.0.0
#   Attempting uninstall: tensorflow-addons
#     Found existing installation: tensorflow-addons 0.16.1
#     Uninstalling tensorflow-addons-0.16.1:
#       Successfully uninstalled tensorflow-addons-0.16.1
# Successfully installed tensorflow-addons-0.20.0 typeguard-2.13.3

# %%
#import tensorflow.keras as keras
#from tensorflow.keras import layers
import tensorflow
import tensorflow_addons as tfa
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.constraints import MaxNorm
from tensorflow.keras.models import Sequential,load_model, Model 
from tensorflow.keras.optimizers import SGD, Adadelta
#from keras.utils import np_utils
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import backend as K
from tensorflow.keras.applications import VGG19
from keras import applications
# Out:
# 2023-06-02 04:57:19.565430: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-02 04:57:19.624385: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-02 04:57:21.194507: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /nfs/home/kjs4242/.local/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
def set_gpus(*gpu_indices):
    # Get list of GPUs
    gpus = tensorflow.config.experimental.list_physical_devices('GPU')
    print("Num GPUs Available: ", len(gpus))

    if gpus:
        visible_gpus = [gpus[i] for i in gpu_indices]
        try:
            # Only use specified GPUs and ignore the others
            tensorflow.config.experimental.set_visible_devices(visible_gpus, 'GPU')
            for gpu in visible_gpus:
                tensorflow.config.experimental.set_memory_growth(gpu, True)
            print("Using GPUs: ", [gpu.name for gpu in visible_gpus])
        except RuntimeError as e:
            print(e)
    return visible_gpus

# Call the function with the indices of the GPUs you want to use
visible_gpus = set_gpus(0, 1, 2, 3, 4)  # Use the second, third, fourth, and fifth GPU

# Extract names of the GPUs being used
gpu_names = ['/device:GPU:' + gpu.name.split(':')[-1] for gpu in visible_gpus]

strategy = tensorflow.distribute.MirroredStrategy(devices=gpu_names)
# Out:
# Num GPUs Available:  5
# Visible devices cannot be modified after being initialized
# WARNING:tensorflow:NCCL is not supported when using virtual GPUs, fallingback to reduction to one device
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3', '/job:localhost/replica:0/task:0/device:GPU:4')

# %%
# Setting common model parameters and hyperparameters
input_shape = (218,178,3)
num_classes = 1
epochs = 100
batch_size=32

# %%
my_callbacks = [EarlyStopping(monitor = "val_loss", patience=3,\
                  verbose=1, min_delta=0.001)]

# %% [markdown]
# ## Model 1 - Custom Model

# %% [markdown]
# ### Model Architecture Summary
# The model architecture used is a convolutional neural network (CNN) commonly used for image classification tasks. Here is a breakdown of the different layers and their functions:
#
# 1. Conv2D layer with 32 filters and a kernel size of (3, 3): This layer performs convolutional operations on the input images, extracting local features using the 32 filters. The activation function used is ReLU (Rectified Linear Unit), which introduces non-linearity to the model.
#
# 2. BatchNormalization layer: This layer normalizes the activations of the previous layer, helping to stabilize and speed up the training process.
#
# 3. Conv2D layer with 64 filters and a kernel size of (3, 3): Similar to the first Conv2D layer, this layer performs convolutional operations on the previous layer's output, extracting additional features.
#
# 4. MaxPooling2D layer with a pool size of (2, 2): This layer reduces the spatial dimensions of the input by performing a downsampling operation, taking the maximum value within each 2x2 window. It helps to reduce the computational complexity and extract dominant features.
#
# 5. Dropout layer with a rate of 0.25: Dropout is a regularization technique that randomly sets a fraction of input units to 0 at each update during training. It helps prevent overfitting by introducing noise and forcing the network to learn more robust features.
#
# 6. Flatten layer: This layer flattens the previous layer's output into a 1-dimensional vector. It prepares the data for the fully connected layers that follow.
#
# 7. Dense layer with 128 units and ReLU activation: This fully connected layer connects every neuron from the previous layer to the current layer. It applies a linear transformation to the input data and applies the ReLU activation function.
#
# 8. Dropout layer with a rate of 0.5: Another dropout layer is added after the first fully connected layer to further regularize the model.
#
# 9. Dense layer with 1 unit and sigmoid activation: This final dense layer is responsible for the binary classification task (1 or 0). The sigmoid activation function squashes the output into the range of [0, 1], representing the probability of the input belonging to the positive class.
#
# In summary, this model consists of convolutional layers to extract features from input images, pooling layers to downsample the spatial dimensions, fully connected layers for classification, and dropout layers for regularization.

# %% [markdown]
# ### Training and saving model

# %%
def base_model_1(input_shape):
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
   
    return model

# %%
# ## Building the first model
model_custom = base_model_1(input_shape)
model_custom.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 216, 176, 32)      896
#
#  batch_normalization_1 (Batc  (None, 216, 176, 32)     128
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 214, 174, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 107, 87, 64)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 107, 87, 64)       0
#
#  flatten_1 (Flatten)         (None, 595776)            0
#
#  dense_2 (Dense)             (None, 128)               76259456
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 76,279,105
# Trainable params: 76,279,041
# Non-trainable params: 64
# _________________________________________________________________

# %%
# Train model
model_custom.compile(loss=BinaryCrossentropy(from_logits=False),
              optimizer=Adadelta(),
              metrics=['accuracy', \
                       tensorflow.keras.metrics.AUC(), \
                       tfa.metrics.F1Score(num_classes=num_classes)])

# model_custom.compile(loss=BinaryCrossentropy(from_logits=False),
#               optimizer=Adadelta(),
#               metrics=['accuracy', \
#                        tensorflow.keras.metrics.AUC()])

# %%
history_custom = model_custom.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test), \
          callbacks=my_callbacks)
# Out:
# Epoch 1/100
# 2023-05-28 17:49:16.550767: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout_2/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-05-28 17:49:17.610185: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8900
# 2023-05-28 17:49:18.281028: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-05-28 17:49:18.774182: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x430f8890 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-28 17:49:18.774242: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 17:49:18.774262: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (1): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 17:49:18.774277: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (2): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 17:49:18.774293: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (3): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 17:49:18.774306: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (4): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 17:49:18.774316: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (5): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 17:49:18.774325: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (6): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 17:49:18.774344: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (7): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 17:49:18.786401: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-28 17:49:18.922574: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-05-28 17:49:19.006245: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 938/938 [==============================] - 69s 68ms/step - loss: 0.5454 - accuracy: 0.7301 - auc: 0.8017 - f1_score: 0.6443 - val_loss: 0.3729 - val_accuracy: 0.8476 - val_auc: 0.9212 - val_f1_score: 0.6477
# Epoch 2/100
# 938/938 [==============================] - 62s 66ms/step - loss: 0.3934 - accuracy: 0.8270 - auc: 0.9027 - f1_score: 0.6443 - val_loss: 0.3327 - val_accuracy: 0.8543 - val_auc: 0.9411 - val_f1_score: 0.6477
# Epoch 3/100
# 938/938 [==============================] - 61s 65ms/step - loss: 0.3376 - accuracy: 0.8550 - auc: 0.9290 - f1_score: 0.6443 - val_loss: 0.2988 - val_accuracy: 0.8719 - val_auc: 0.9475 - val_f1_score: 0.6477
# Epoch 4/100
# 938/938 [==============================] - 61s 65ms/step - loss: 0.3079 - accuracy: 0.8703 - auc: 0.9409 - f1_score: 0.6443 - val_loss: 0.2801 - val_accuracy: 0.8834 - val_auc: 0.9524 - val_f1_score: 0.6477
# Epoch 5/100
# 938/938 [==============================] - 61s 65ms/step - loss: 0.2850 - accuracy: 0.8795 - auc: 0.9491 - f1_score: 0.6443 - val_loss: 0.2756 - val_accuracy: 0.8824 - val_auc: 0.9546 - val_f1_score: 0.6477
# Epoch 6/100
# 938/938 [==============================] - 61s 65ms/step - loss: 0.2677 - accuracy: 0.8901 - auc: 0.9552 - f1_score: 0.6443 - val_loss: 0.2650 - val_accuracy: 0.8913 - val_auc: 0.9564 - val_f1_score: 0.6477
# Epoch 7/100
# 938/938 [==============================] - 61s 65ms/step - loss: 0.2556 - accuracy: 0.8936 - auc: 0.9591 - f1_score: 0.6444 - val_loss: 0.2667 - val_accuracy: 0.8891 - val_auc: 0.9568 - val_f1_score: 0.6477
# Epoch 8/100
# 938/938 [==============================] - 61s 65ms/step - loss: 0.2411 - accuracy: 0.9008 - auc: 0.9636 - f1_score: 0.6443 - val_loss: 0.2657 - val_accuracy: 0.8882 - val_auc: 0.9594 - val_f1_score: 0.6477
# Epoch 9/100
# 938/938 [==============================] - 61s 65ms/step - loss: 0.2304 - accuracy: 0.9053 - auc: 0.9667 - f1_score: 0.6444 - val_loss: 0.2820 - val_accuracy: 0.8858 - val_auc: 0.9570 - val_f1_score: 0.6477
# Epoch 9: early stopping

# %%
#Create a directory named saved models and then run this cell
model_name = "saved_models/Model_Custom_" + classification_attribute + ".h5"
model_custom.save(model_name) ## Saving the model

# %% [markdown]
# ### Finding model performance

# %%
curr_model = load_model("saved_models/Model_Custom_Smiling.h5")
# Out:
# 2023-06-02 04:57:29.185139: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9599 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# 2023-06-02 04:57:29.186374: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9599 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1b:00.0, compute capability: 7.5
# 2023-06-02 04:57:29.187342: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 9599 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:3d:00.0, compute capability: 7.5
# 2023-06-02 04:57:29.188328: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 9599 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:3e:00.0, compute capability: 7.5
# 2023-06-02 04:57:29.189313: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 9599 MB memory:  -> device: 4, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:88:00.0, compute capability: 7.5
# 2023-06-02 04:57:29.190337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 9599 MB memory:  -> device: 5, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:89:00.0, compute capability: 7.5
# 2023-06-02 04:57:29.191277: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 9599 MB memory:  -> device: 6, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:b1:00.0, compute capability: 7.5
# 2023-06-02 04:57:29.192207: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 9599 MB memory:  -> device: 7, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:b2:00.0, compute capability: 7.5

# %%
score = curr_model.evaluate(x_test, y_test, verbose=0)
# Out:
# 2023-06-02 04:57:38.884476: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8900
# 2023-06-02 04:57:39.559227: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory

# %%
print("Testing loss: ", score[0])
print("Testing accuracy: ", score[1])
print("Testing AUC: ", score[2])
print("Testing F1 score: ", score[3])
# Out:
# Testing loss:  0.2819676399230957
# Testing accuracy:  0.8858000040054321
# Testing AUC:  0.956981897354126
# Testing F1 score:  [0.64771116]

# %% [markdown]
# #### Plot of training vs validation loss

# %%
plt.figure(figsize=[6,4])
plt.plot(history_custom.history['loss'],'r',linewidth=3.0)
plt.plot(history_custom.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Loss Curves')

# %% [markdown]
# ### Summary of hyperparameters used

# %% [markdown]
# Below is a description of the hyperparameters used in the provided code and the reasons behind their choices:
#
# 1. Conv2D layer filters (32 and 64): The number of filters determines the depth or the number of channels in the output feature maps. In this case, 32 filters are chosen for the first Conv2D layer, and 64 filters are chosen for the second Conv2D layer. These values are typically selected based on the complexity of the problem and the size of the dataset. Higher values can capture more complex features but also increase computational requirements.
#
# 2. Kernel size (3, 3): The kernel size specifies the spatial extent of the convolutional window. A (3, 3) kernel scans a 3x3 window over the input image. Smaller kernel sizes focus on capturing local details, while larger kernel sizes capture more global features. The choice of (3, 3) is a common practice that balances capturing local and global features efficiently.
#
# 3. Activation function 'relu': The Rectified Linear Unit (ReLU) activation function is chosen for the Conv2D and Dense layers. ReLU introduces non-linearity to the model and has been proven effective in deep learning models. It helps to alleviate the vanishing gradient problem, allowing the network to learn more complex representations.
#
# 4. BatchNormalization: Batch normalization is applied after the first Conv2D layer. It normalizes the activations within each batch, reducing internal covariate shift and improving the training process. It helps to stabilize and accelerate the training by reducing the dependency on the scale of the activation values.
#
# 5. MaxPooling2D layer pool size (2, 2): Max pooling is used to downsample the spatial dimensions of the input. A pool size of (2, 2) means that the input is divided into non-overlapping 2x2 windows, and the maximum value within each window is selected. This downsampling operation helps in capturing the most dominant features while reducing the computational complexity.
#
# 6. Dropout rates (0.25 and 0.5): Dropout is used after the first Conv2D layer and the first Dense layer with dropout rates of 0.25 and 0.5, respectively. Dropout is a regularization technique that randomly sets a fraction of the input units to 0 during training. It helps to prevent overfitting by reducing the reliance on specific neurons and encourages the network to learn more robust features.
#
# 7. Dense layer units (128 and 1): The number of units in the Dense layers determines the dimensionality of the output space. In this case, 128 units are chosen for the first Dense layer, and 1 unit is chosen for the final Dense layer. The value of 128 is often selected based on the complexity of the problem and the number of trainable parameters. The final Dense layer with 1 unit is suitable for binary classification, where the output represents the probability of belonging to the positive class.
#
# In summary, these hyperparameters are chosen based on best practices and empirical evidence in deep learning. The specific choices depend on the problem at hand, the available data, and the desired trade-off between model complexity and computational efficiency.

# %%
del model_custom ## Deleting the model variable to save memory

# %% [markdown]
# ## Model 2 - Transfer learning

# %% [markdown]
# ### Summary of Model Architecture
#
# Apologies for the confusion. Here's a summary of the model architecture:
#
# 1. Base Model: ResNet101
#    - The base model is ResNet101, a popular convolutional neural network architecture known for its deep structure and residual connections.
#    - The weights of the model are initialized using pre-trained weights from the ImageNet dataset.
#    - The top layer (classification layer) is excluded from the model using the `include_top=False` argument.
#
# 2. Freezing Layers:
#    - The first 234 layers of the ResNet101 model are frozen, which means their weights are not updated during training.
#    - By setting `layer.trainable = False` for these layers, their parameters are fixed.
#
# 3. Custom Layers:
#    - The output of the base model is passed to additional layers to perform fine-tuning and adapt the model to a specific task.
#    - Flatten layer: Flattens the output from the base model into a 1-dimensional vector.
#    - Dense layer: Adds a fully connected layer with 1024 units and ReLU activation function.
#    - Batch Normalization layer: Normalizes the activations of the previous layer to stabilize training.
#    - Dropout layer: Randomly sets a fraction of input units to 0 during training to prevent overfitting.
#    - Final Dense layer: Outputs the predictions with the number of units equal to the number of classes in the target task, using a softmax activation function.
#
# 4. Final Model:
#    - The final model is created by specifying the input as the input of the base model and the output as the output of the custom layers.
#    - `model_final = Model(model2.input, predictions)` binds the input and output layers together to form the complete model architecture.
#
# This architecture allows you to leverage the pre-trained ResNet101 model while adding custom layers on top to adapt it to a specific classification task.

# %% [markdown]
# ### Training and saving model

# %%
def tl_model_1(input_shape):
    model2 = applications.ResNet101(weights = "imagenet", include_top=False, input_shape = input_shape)
    for layer in model2.layers[:234]:
        layer.trainable = False
    
    #Adding custom Layers 
    x = model2.output
    x = Flatten()(x)
    x = Dense(1024, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation="sigmoid")(x)

    # creating the final model 
    model_final = Model(model2.input, predictions)
       
    return model_final

# %%
model_tl = tl_model_1(input_shape)
model_tl.summary()
# Out:
# 2023-05-28 18:21:24.462674: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9599 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# 2023-05-28 18:21:24.463973: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9599 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1b:00.0, compute capability: 7.5
# 2023-05-28 18:21:24.465037: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 9599 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:3d:00.0, compute capability: 7.5
# 2023-05-28 18:21:24.466078: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 9599 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:3e:00.0, compute capability: 7.5
# 2023-05-28 18:21:24.467103: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 9599 MB memory:  -> device: 4, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:88:00.0, compute capability: 7.5
# 2023-05-28 18:21:24.468101: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 9599 MB memory:  -> device: 5, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:89:00.0, compute capability: 7.5
# 2023-05-28 18:21:24.469026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 9599 MB memory:  -> device: 6, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:b1:00.0, compute capability: 7.5
# 2023-05-28 18:21:24.469891: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 9599 MB memory:  -> device: 7, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:b2:00.0, compute capability: 7.5
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 218, 178, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 224, 184, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 109, 89, 64)  9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 109, 89, 64)  256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 109, 89, 64)  0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 111, 91, 64)  0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 55, 45, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 55, 45, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 55, 45, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 55, 45, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 55, 45, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 55, 45, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 55, 45, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 55, 45, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 55, 45, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 55, 45, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 55, 45, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 55, 45, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 55, 45, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 55, 45, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 55, 45, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 55, 45, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 55, 45, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 55, 45, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 55, 45, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 55, 45, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 55, 45, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 55, 45, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 55, 45, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 23, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 23, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 23, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 23, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 23, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 23, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 23, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 23, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 23, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 23, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 23, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 23, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 23, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 23, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 23, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 23, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 23, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 23, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 23, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 23, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 23, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 23, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 23, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 23, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 23, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 23, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 23, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 23, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 12, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 12, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 12, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 12, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 12, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 12, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 12, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 12, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 12, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 12, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 12, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 12, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 12, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 12, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 12, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 12, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 12, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 12, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 12, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 12, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 12, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 12, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 12, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 12, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 12, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 12, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 12, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 12, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 12, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 12, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 12, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 12, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv4_block7_1_conv (Conv2D)   (None, 14, 12, 256)  262400      ['conv4_block6_out[0][0]']
#
#  conv4_block7_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block7_1_conv[0][0]']
#  ization)
#
#  conv4_block7_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block7_1_bn[0][0]']
#  n)
#
#  conv4_block7_2_conv (Conv2D)   (None, 14, 12, 256)  590080      ['conv4_block7_1_relu[0][0]']
#
#  conv4_block7_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block7_2_conv[0][0]']
#  ization)
#
#  conv4_block7_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block7_2_bn[0][0]']
#  n)
#
#  conv4_block7_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block7_2_relu[0][0]']
#                                 )
#
#  conv4_block7_3_bn (BatchNormal  (None, 14, 12, 1024  4096       ['conv4_block7_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block7_add (Add)         (None, 14, 12, 1024  0           ['conv4_block6_out[0][0]',
#                                 )                                 'conv4_block7_3_bn[0][0]']
#
#  conv4_block7_out (Activation)  (None, 14, 12, 1024  0           ['conv4_block7_add[0][0]']
#                                 )
#
#  conv4_block8_1_conv (Conv2D)   (None, 14, 12, 256)  262400      ['conv4_block7_out[0][0]']
#
#  conv4_block8_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block8_1_conv[0][0]']
#  ization)
#
#  conv4_block8_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block8_1_bn[0][0]']
#  n)
#
#  conv4_block8_2_conv (Conv2D)   (None, 14, 12, 256)  590080      ['conv4_block8_1_relu[0][0]']
#
#  conv4_block8_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block8_2_conv[0][0]']
#  ization)
#
#  conv4_block8_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block8_2_bn[0][0]']
#  n)
#
#  conv4_block8_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block8_2_relu[0][0]']
#                                 )
#
#  conv4_block8_3_bn (BatchNormal  (None, 14, 12, 1024  4096       ['conv4_block8_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block8_add (Add)         (None, 14, 12, 1024  0           ['conv4_block7_out[0][0]',
#                                 )                                 'conv4_block8_3_bn[0][0]']
#
#  conv4_block8_out (Activation)  (None, 14, 12, 1024  0           ['conv4_block8_add[0][0]']
#                                 )
#
#  conv4_block9_1_conv (Conv2D)   (None, 14, 12, 256)  262400      ['conv4_block8_out[0][0]']
#
#  conv4_block9_1_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block9_1_conv[0][0]']
#  ization)
#
#  conv4_block9_1_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block9_1_bn[0][0]']
#  n)
#
#  conv4_block9_2_conv (Conv2D)   (None, 14, 12, 256)  590080      ['conv4_block9_1_relu[0][0]']
#
#  conv4_block9_2_bn (BatchNormal  (None, 14, 12, 256)  1024       ['conv4_block9_2_conv[0][0]']
#  ization)
#
#  conv4_block9_2_relu (Activatio  (None, 14, 12, 256)  0          ['conv4_block9_2_bn[0][0]']
#  n)
#
#  conv4_block9_3_conv (Conv2D)   (None, 14, 12, 1024  263168      ['conv4_block9_2_relu[0][0]']
#                                 )
#
#  conv4_block9_3_bn (BatchNormal  (None, 14, 12, 1024  4096       ['conv4_block9_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block9_add (Add)         (None, 14, 12, 1024  0           ['conv4_block8_out[0][0]',
# ...
#  lization)                      )
#
#  conv4_block21_add (Add)        (None, 14, 12, 1024  0           ['conv4_block20_out[0][0]',
#                                 )                                 'conv4_block21_3_bn[0][0]']
#
#  conv4_block21_out (Activation)  (None, 14, 12, 1024  0          ['conv4_block21_add[0][0]']
#                                 )
#
#  conv4_block22_1_conv (Conv2D)  (None, 14, 12, 256)  262400      ['conv4_block21_out[0][0]']
#
#  conv4_block22_1_bn (BatchNorma  (None, 14, 12, 256)  1024       ['conv4_block22_1_conv[0][0]']
#  lization)
#
#  conv4_block22_1_relu (Activati  (None, 14, 12, 256)  0          ['conv4_block22_1_bn[0][0]']
#  on)
#
#  conv4_block22_2_conv (Conv2D)  (None, 14, 12, 256)  590080      ['conv4_block22_1_relu[0][0]']
#
#  conv4_block22_2_bn (BatchNorma  (None, 14, 12, 256)  1024       ['conv4_block22_2_conv[0][0]']
#  lization)
#
#  conv4_block22_2_relu (Activati  (None, 14, 12, 256)  0          ['conv4_block22_2_bn[0][0]']
#  on)
#
#  conv4_block22_3_conv (Conv2D)  (None, 14, 12, 1024  263168      ['conv4_block22_2_relu[0][0]']
#                                 )
#
#  conv4_block22_3_bn (BatchNorma  (None, 14, 12, 1024  4096       ['conv4_block22_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block22_add (Add)        (None, 14, 12, 1024  0           ['conv4_block21_out[0][0]',
#                                 )                                 'conv4_block22_3_bn[0][0]']
#
#  conv4_block22_out (Activation)  (None, 14, 12, 1024  0          ['conv4_block22_add[0][0]']
#                                 )
#
#  conv4_block23_1_conv (Conv2D)  (None, 14, 12, 256)  262400      ['conv4_block22_out[0][0]']
#
#  conv4_block23_1_bn (BatchNorma  (None, 14, 12, 256)  1024       ['conv4_block23_1_conv[0][0]']
#  lization)
#
#  conv4_block23_1_relu (Activati  (None, 14, 12, 256)  0          ['conv4_block23_1_bn[0][0]']
#  on)
#
#  conv4_block23_2_conv (Conv2D)  (None, 14, 12, 256)  590080      ['conv4_block23_1_relu[0][0]']
#
#  conv4_block23_2_bn (BatchNorma  (None, 14, 12, 256)  1024       ['conv4_block23_2_conv[0][0]']
#  lization)
#
#  conv4_block23_2_relu (Activati  (None, 14, 12, 256)  0          ['conv4_block23_2_bn[0][0]']
#  on)
#
#  conv4_block23_3_conv (Conv2D)  (None, 14, 12, 1024  263168      ['conv4_block23_2_relu[0][0]']
#                                 )
#
#  conv4_block23_3_bn (BatchNorma  (None, 14, 12, 1024  4096       ['conv4_block23_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block23_add (Add)        (None, 14, 12, 1024  0           ['conv4_block22_out[0][0]',
#                                 )                                 'conv4_block23_3_bn[0][0]']
#
#  conv4_block23_out (Activation)  (None, 14, 12, 1024  0          ['conv4_block23_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 6, 512)    524800      ['conv4_block23_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 6, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 6, 2048)   2099200     ['conv4_block23_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 6, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 6, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 6, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 6, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 6, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 6, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 6, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 6, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 6, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 6, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 6, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 6, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 6, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 6, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 6, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 6, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 6, 2048)   0           ['conv5_block3_add[0][0]']
#
#  flatten (Flatten)              (None, 86016)        0           ['conv5_block3_out[0][0]']
#
#  dense (Dense)                  (None, 1024)         88081408    ['flatten[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1024)        4096        ['dense[0][0]']
#  alization)
#
#  dropout (Dropout)              (None, 1024)         0           ['batch_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 1)            1025        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 130,744,705
# Trainable params: 111,747,841
# Non-trainable params: 18,996,864
# __________________________________________________________________________________________________

# %%
model_tl.compile(loss=BinaryCrossentropy(from_logits=False),
              optimizer=Adadelta(),
              metrics=['accuracy', \
                       tensorflow.keras.metrics.AUC(), \
                       tfa.metrics.F1Score(num_classes=num_classes)])

# model_tl.compile(loss=BinaryCrossentropy(from_logits=False),
#               optimizer=Adadelta(),
#               metrics=['accuracy', \
#                        tensorflow.keras.metrics.AUC()])

# %%
history_tl = model_tl.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test),
          callbacks=my_callbacks)
# Out:
# Epoch 1/100
# 2023-05-28 18:21:43.983134: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8900
# 2023-05-28 18:21:44.647918: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-05-28 18:21:45.329003: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x467b7e70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-28 18:21:45.329061: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 18:21:45.329079: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (1): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 18:21:45.329091: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (2): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 18:21:45.329100: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (3): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 18:21:45.329113: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (4): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 18:21:45.329123: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (5): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 18:21:45.329135: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (6): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 18:21:45.329148: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (7): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 18:21:45.341362: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-28 18:21:45.473750: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-05-28 18:21:45.556062: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 938/938 [==============================] - 159s 142ms/step - loss: 0.6006 - accuracy: 0.7365 - auc: 0.8132 - f1_score: 0.6443 - val_loss: 0.3794 - val_accuracy: 0.8377 - val_auc: 0.9155 - val_f1_score: 0.6477
# Epoch 2/100
# 938/938 [==============================] - 130s 139ms/step - loss: 0.3920 - accuracy: 0.8381 - auc: 0.9174 - f1_score: 0.6443 - val_loss: 0.3336 - val_accuracy: 0.8634 - val_auc: 0.9364 - val_f1_score: 0.6477
# Epoch 3/100
# 938/938 [==============================] - 130s 139ms/step - loss: 0.3294 - accuracy: 0.8663 - auc: 0.9407 - f1_score: 0.6443 - val_loss: 0.3174 - val_accuracy: 0.8734 - val_auc: 0.9444 - val_f1_score: 0.6477
# Epoch 4/100
# 938/938 [==============================] - 129s 138ms/step - loss: 0.2825 - accuracy: 0.8839 - auc: 0.9548 - f1_score: 0.6443 - val_loss: 0.3056 - val_accuracy: 0.8782 - val_auc: 0.9484 - val_f1_score: 0.6477
# Epoch 5/100
# 938/938 [==============================] - 130s 138ms/step - loss: 0.2523 - accuracy: 0.8981 - auc: 0.9630 - f1_score: 0.6443 - val_loss: 0.3015 - val_accuracy: 0.8817 - val_auc: 0.9510 - val_f1_score: 0.6477
# Epoch 6/100
# 938/938 [==============================] - 130s 139ms/step - loss: 0.2288 - accuracy: 0.9071 - auc: 0.9690 - f1_score: 0.6443 - val_loss: 0.2924 - val_accuracy: 0.8840 - val_auc: 0.9535 - val_f1_score: 0.6477
# Epoch 7/100
# 938/938 [==============================] - 129s 138ms/step - loss: 0.1987 - accuracy: 0.9189 - auc: 0.9758 - f1_score: 0.6443 - val_loss: 0.2897 - val_accuracy: 0.8856 - val_auc: 0.9550 - val_f1_score: 0.6477
# Epoch 8/100
# 938/938 [==============================] - 130s 139ms/step - loss: 0.1791 - accuracy: 0.9259 - auc: 0.9802 - f1_score: 0.6443 - val_loss: 0.2868 - val_accuracy: 0.8885 - val_auc: 0.9561 - val_f1_score: 0.6477
# Epoch 9/100
# 938/938 [==============================] - 130s 139ms/step - loss: 0.1641 - accuracy: 0.9316 - auc: 0.9831 - f1_score: 0.6443 - val_loss: 0.2860 - val_accuracy: 0.8886 - val_auc: 0.9568 - val_f1_score: 0.6477
# Epoch 10/100
# 938/938 [==============================] - 131s 140ms/step - loss: 0.1442 - accuracy: 0.9422 - auc: 0.9870 - f1_score: 0.6443 - val_loss: 0.2846 - val_accuracy: 0.8910 - val_auc: 0.9576 - val_f1_score: 0.6477
# Epoch 11/100
# 938/938 [==============================] - 129s 138ms/step - loss: 0.1338 - accuracy: 0.9455 - auc: 0.9889 - f1_score: 0.6443 - val_loss: 0.2883 - val_accuracy: 0.8910 - val_auc: 0.9578 - val_f1_score: 0.6477
# Epoch 12/100
# 938/938 [==============================] - 129s 138ms/step - loss: 0.1197 - accuracy: 0.9521 - auc: 0.9912 - f1_score: 0.6443 - val_loss: 0.2860 - val_accuracy: 0.8916 - val_auc: 0.9583 - val_f1_score: 0.6477
# Epoch 13/100
# 938/938 [==============================] - 130s 139ms/step - loss: 0.1096 - accuracy: 0.9569 - auc: 0.9927 - f1_score: 0.6443 - val_loss: 0.2872 - val_accuracy: 0.8920 - val_auc: 0.9584 - val_f1_score: 0.6477
# Epoch 13: early stopping

# %%
#Create a directory named saved models and then run this cell
model_name = "saved_models/Transfer_Learning_ResNet_" + classification_attribute + ".h5"
model_tl.save(model_name) ## Saving the model

# %% [markdown]
# ### Model performance

# %%
curr_model = load_model("saved_models/Transfer_Learning_ResNet_Smiling.h5")

# %%
score = curr_model.evaluate(x_test, y_test, verbose=0)

# %%
print("Testing loss: ", score[0])
print("Testing accuracy: ", score[1])
print("Testing AUC: ", score[2])
print("Testing F1 score: ", score[3])
# Out:
# Testing loss:  0.28719425201416016
# Testing accuracy:  0.8919500112533569
# Testing AUC:  0.9583562612533569
# Testing F1 score:  [0.6476892]

# %% [markdown]
# #### Plot of training vs validation loss

# %%
plt.figure(figsize=[6,4])
plt.plot(history_tl.history['loss'],'r',linewidth=3.0)
plt.plot(history_tl.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Loss Curves')

# %%
curr_model = load_model("saved_models/Transfer_Learning_ResNet_Smiling.h5")

# %%
score = curr_model.evaluate(x_test, y_test, verbose=0)

# %%
print("Testing loss: ", score[0])
print("Testing accuracy: ", score[1])
print("Testing AUC: ", score[2])
print("Testing F1 score: ", score[3])
# Out:
# Testing loss:  0.28719425201416016
# Testing accuracy:  0.8919500112533569
# Testing AUC:  0.9583562612533569
# Testing F1 score:  [0.6476892]

# %% [markdown]
# ### Summary of hyperparameters:
#
# Below is a brief summary of the hyperparameters used in the code and their purposes:
#
# 1. Number of Layers frozen:
#    - The first 234 layers of the ResNet101 model are frozen by setting `layer.trainable = False`.
#    - This is done to prevent updating the weights of these layers during training.
#    - Freezing the early layers is a common practice when fine-tuning pre-trained models, as it helps to retain the knowledge learned from the ImageNet dataset while focusing on adapting the later layers to the specific task.
#
# 2. Custom Layers:
#    - Dense layer: The number of units in this layer is set to 1024 with a ReLU activation function. This choice depends on the complexity of the target task and the desired capacity of the model to learn high-level representations.
#    - The activation function: The ReLU (Rectified Linear Unit) activation function is a common choice for introducing non-linearity in neural networks. It helps the model learn complex relationships between the input and the output by mapping negative values to zero and leaving positive values unchanged. ReLU has been shown to work well in many deep learning architectures. It is also very easy to compute the gradients for ReLU functions.
#    - Batch Normalization layer: This layer normalizes the activations of the previous layer, which helps stabilize the training process by reducing internal covariate shift.
#    - Dropout layer: Dropout with a rate of 0.5 is applied after the Dense layer to randomly set a fraction of input units to 0 during training. This regularizes the model and reduces the risk of overfitting.
#    - Final Dense layer activation function: The softmax activation function is used to produce class probabilities. This is usual for multi
#
# The specific values chosen for these hyperparameters can vary based on the dataset, the complexity of the task, and the available computational resources. The selection is often based on empirical experimentation and tuning to achieve optimal performance and balance between model capacity and overfitting.

# %% [markdown]
# ## Model 3 - Transfer learning

# %% [markdown]
# ### Model Architecture Summary
#
# Here, the model architecture based on the VGG16 convolutional neural network, with some modifications and additional layers is contructed to implement transfer learning. Here is a summary of the architecture:
#
# 1. Pretrained Base Model:
#    The base model is VGG16, which is initialized with pre-trained weights from the "imagenet" dataset. The `include_top=False` argument excludes the fully connected layers at the top of the network.
#
# 2. Freezing Layers:
#    The code loops through the layers of the base model (`model2`) and freezes the first 205 layers by setting their `trainable` attribute to `False`. This means those layers' weights will not be updated during training.
#
# 3. Custom Layers:
#    The output of the base model is passed through additional layers to customize the model. Here are the custom layers added:
#    - Flatten: Flattens the tensor output from the base model to a 1-dimensional vector.
#    - Dense(1024, activation="relu"): A fully connected layer with 1024 units and ReLU activation function.
#    - BatchNormalization: Normalizes the activations of the previous layer, reducing internal covariate shift.
#    - Dropout(0.5): Applies dropout regularization with a rate of 0.5, randomly setting 50% of the input units to 0 during training.
#    - Dense(256, activation="relu"): Another fully connected layer with 256 units and ReLU activation function.
#    - BatchNormalization
#    - Dropout(0.5)
#
# 4. Final Layers:
#    The output of the last dropout layer is fed into a dense layer with a number of units equal to the `num_classes` variable. The activation function used is sigmoid, indicating a multi-label classification problem.
#
# 5. Final Model:
#    The `model_final` is created by specifying the inputs as the input of the `model2` and the outputs as the predictions from the last sigmoid dense layer.
#
# In summary, the code creates a modified VGG16 model by freezing the first 205 layers, adding custom layers for further feature extraction and classification, and generating the final model for the specific task at hand.

# %% [markdown]
# ### Training and saving model

# %%
def tl_model_2(input_shape):
    model2 = applications.VGG16(weights = "imagenet", include_top=False, input_shape = input_shape)
    for layer in model2.layers[:205]:
        layer.trainable = False
    
    #Adding custom Layers 
    x = model2.output
    x = Flatten()(x)
    x = Dense(1024, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation="sigmoid")(x)

    # creating the final model 
    model_final = Model(model2.input, predictions)
       
    return model_final

# %%
model_tl_2 = tl_model_2(input_shape)
model_tl_2.summary()
# Out:
# 2023-05-28 19:19:10.528723: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9599 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# 2023-05-28 19:19:10.529949: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9599 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1b:00.0, compute capability: 7.5
# 2023-05-28 19:19:10.530960: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 9599 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:3d:00.0, compute capability: 7.5
# 2023-05-28 19:19:10.532025: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 9599 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:3e:00.0, compute capability: 7.5
# 2023-05-28 19:19:10.532993: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 9599 MB memory:  -> device: 4, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:88:00.0, compute capability: 7.5
# 2023-05-28 19:19:10.534017: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 9599 MB memory:  -> device: 5, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:89:00.0, compute capability: 7.5
# 2023-05-28 19:19:10.534959: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 9599 MB memory:  -> device: 6, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:b1:00.0, compute capability: 7.5
# 2023-05-28 19:19:10.535869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 9599 MB memory:  -> device: 7, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:b2:00.0, compute capability: 7.5
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 218, 178, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 218, 178, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 218, 178, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 109, 89, 64)       0
#
#  block2_conv1 (Conv2D)       (None, 109, 89, 128)      73856
#
#  block2_conv2 (Conv2D)       (None, 109, 89, 128)      147584
#
#  block2_pool (MaxPooling2D)  (None, 54, 44, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 54, 44, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 54, 44, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 54, 44, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 27, 22, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 27, 22, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 27, 22, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 27, 22, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 13, 11, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 13, 11, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 13, 11, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 13, 11, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 6, 5, 512)         0
#
#  flatten (Flatten)           (None, 15360)             0
#
#  dense (Dense)               (None, 1024)              15729664
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 30,712,129
# Trainable params: 15,994,881
# Non-trainable params: 14,717,248
# _________________________________________________________________

# %%
model_tl_2.compile(loss=BinaryCrossentropy(from_logits=False),
              optimizer=Adadelta(),
              metrics=['accuracy', \
                       tensorflow.keras.metrics.AUC(), \
                       tfa.metrics.F1Score(num_classes=num_classes)])

# %%
history_tl_2 = model_tl_2.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test),
          callbacks=my_callbacks)
# Out:
# Epoch 1/100
# 2023-05-28 19:19:17.468893: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8900
# 2023-05-28 19:19:18.137416: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-05-28 19:19:19.754065: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x42f5d340 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-28 19:19:19.754120: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 19:19:19.754135: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (1): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 19:19:19.754145: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (2): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 19:19:19.754155: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (3): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 19:19:19.754165: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (4): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 19:19:19.754175: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (5): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 19:19:19.754185: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (6): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 19:19:19.754195: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (7): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-28 19:19:19.766378: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-28 19:19:19.910444: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-05-28 19:19:19.994165: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 938/938 [==============================] - 75s 73ms/step - loss: 0.9684 - accuracy: 0.5403 - auc: 0.5567 - f1_score: 0.6443 - val_loss: 0.6630 - val_accuracy: 0.6316 - val_auc: 0.6846 - val_f1_score: 0.6477
# Epoch 2/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.8536 - accuracy: 0.5951 - auc: 0.6331 - f1_score: 0.6443 - val_loss: 0.5985 - val_accuracy: 0.6880 - val_auc: 0.7595 - val_f1_score: 0.6477
# Epoch 3/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.7905 - accuracy: 0.6287 - auc: 0.6779 - f1_score: 0.6443 - val_loss: 0.5539 - val_accuracy: 0.7232 - val_auc: 0.7993 - val_f1_score: 0.6477
# Epoch 4/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.7481 - accuracy: 0.6535 - auc: 0.7118 - f1_score: 0.6443 - val_loss: 0.5249 - val_accuracy: 0.7431 - val_auc: 0.8225 - val_f1_score: 0.6477
# Epoch 5/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.7148 - accuracy: 0.6698 - auc: 0.7345 - f1_score: 0.6443 - val_loss: 0.5035 - val_accuracy: 0.7572 - val_auc: 0.8388 - val_f1_score: 0.6477
# Epoch 6/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.6759 - accuracy: 0.6911 - auc: 0.7593 - f1_score: 0.6443 - val_loss: 0.4872 - val_accuracy: 0.7668 - val_auc: 0.8502 - val_f1_score: 0.6477
# Epoch 7/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.6568 - accuracy: 0.6995 - auc: 0.7719 - f1_score: 0.6443 - val_loss: 0.4731 - val_accuracy: 0.7763 - val_auc: 0.8592 - val_f1_score: 0.6477
# Epoch 8/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.6414 - accuracy: 0.7120 - auc: 0.7857 - f1_score: 0.6443 - val_loss: 0.4631 - val_accuracy: 0.7824 - val_auc: 0.8663 - val_f1_score: 0.6477
# Epoch 9/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.6337 - accuracy: 0.7190 - auc: 0.7925 - f1_score: 0.6443 - val_loss: 0.4529 - val_accuracy: 0.7883 - val_auc: 0.8720 - val_f1_score: 0.6477
# Epoch 10/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.6146 - accuracy: 0.7275 - auc: 0.8017 - f1_score: 0.6443 - val_loss: 0.4453 - val_accuracy: 0.7932 - val_auc: 0.8767 - val_f1_score: 0.6477
# Epoch 11/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.5943 - accuracy: 0.7368 - auc: 0.8140 - f1_score: 0.6443 - val_loss: 0.4376 - val_accuracy: 0.7990 - val_auc: 0.8806 - val_f1_score: 0.6477
# Epoch 12/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.5758 - accuracy: 0.7433 - auc: 0.8230 - f1_score: 0.6443 - val_loss: 0.4326 - val_accuracy: 0.8008 - val_auc: 0.8843 - val_f1_score: 0.6477
# Epoch 13/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.5756 - accuracy: 0.7468 - auc: 0.8254 - f1_score: 0.6443 - val_loss: 0.4263 - val_accuracy: 0.8051 - val_auc: 0.8872 - val_f1_score: 0.6477
# Epoch 14/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.5715 - accuracy: 0.7488 - auc: 0.8288 - f1_score: 0.6443 - val_loss: 0.4224 - val_accuracy: 0.8059 - val_auc: 0.8900 - val_f1_score: 0.6477
# Epoch 15/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.5495 - accuracy: 0.7583 - auc: 0.8385 - f1_score: 0.6443 - val_loss: 0.4174 - val_accuracy: 0.8088 - val_auc: 0.8927 - val_f1_score: 0.6477
# Epoch 16/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.5463 - accuracy: 0.7633 - auc: 0.8420 - f1_score: 0.6443 - val_loss: 0.4132 - val_accuracy: 0.8142 - val_auc: 0.8944 - val_f1_score: 0.6477
# Epoch 17/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.5478 - accuracy: 0.7616 - auc: 0.8422 - f1_score: 0.6443 - val_loss: 0.4093 - val_accuracy: 0.8162 - val_auc: 0.8966 - val_f1_score: 0.6477
# Epoch 18/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.5348 - accuracy: 0.7670 - auc: 0.8474 - f1_score: 0.6443 - val_loss: 0.4068 - val_accuracy: 0.8174 - val_auc: 0.8983 - val_f1_score: 0.6477
# Epoch 19/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.5283 - accuracy: 0.7685 - auc: 0.8517 - f1_score: 0.6443 - val_loss: 0.4033 - val_accuracy: 0.8209 - val_auc: 0.8999 - val_f1_score: 0.6477
# Epoch 20/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.5123 - accuracy: 0.7756 - auc: 0.8588 - f1_score: 0.6443 - val_loss: 0.4007 - val_accuracy: 0.8213 - val_auc: 0.9014 - val_f1_score: 0.6477
# Epoch 21/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.5198 - accuracy: 0.7735 - auc: 0.8566 - f1_score: 0.6443 - val_loss: 0.3986 - val_accuracy: 0.8232 - val_auc: 0.9027 - val_f1_score: 0.6477
# Epoch 22/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.5074 - accuracy: 0.7796 - auc: 0.8620 - f1_score: 0.6443 - val_loss: 0.3966 - val_accuracy: 0.8247 - val_auc: 0.9040 - val_f1_score: 0.6477
# Epoch 23/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.5024 - accuracy: 0.7830 - auc: 0.8649 - f1_score: 0.6443 - val_loss: 0.3947 - val_accuracy: 0.8246 - val_auc: 0.9051 - val_f1_score: 0.6477
# Epoch 24/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.4927 - accuracy: 0.7868 - auc: 0.8695 - f1_score: 0.6443 - val_loss: 0.3925 - val_accuracy: 0.8276 - val_auc: 0.9061 - val_f1_score: 0.6477
# Epoch 25/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.4963 - accuracy: 0.7875 - auc: 0.8687 - f1_score: 0.6443 - val_loss: 0.3899 - val_accuracy: 0.8288 - val_auc: 0.9073 - val_f1_score: 0.6477
# Epoch 26/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.4930 - accuracy: 0.7863 - auc: 0.8699 - f1_score: 0.6443 - val_loss: 0.3888 - val_accuracy: 0.8309 - val_auc: 0.9080 - val_f1_score: 0.6477
# Epoch 27/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.4753 - accuracy: 0.7954 - auc: 0.8777 - f1_score: 0.6443 - val_loss: 0.3863 - val_accuracy: 0.8314 - val_auc: 0.9092 - val_f1_score: 0.6477
# Epoch 28/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.4774 - accuracy: 0.7960 - auc: 0.8767 - f1_score: 0.6443 - val_loss: 0.3845 - val_accuracy: 0.8323 - val_auc: 0.9100 - val_f1_score: 0.6477
# Epoch 29/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.4734 - accuracy: 0.7971 - auc: 0.8786 - f1_score: 0.6443 - val_loss: 0.3834 - val_accuracy: 0.8332 - val_auc: 0.9108 - val_f1_score: 0.6477
# Epoch 30/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.4777 - accuracy: 0.7972 - auc: 0.8778 - f1_score: 0.6443 - val_loss: 0.3822 - val_accuracy: 0.8343 - val_auc: 0.9114 - val_f1_score: 0.6477
# Epoch 31/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.4736 - accuracy: 0.7968 - auc: 0.8798 - f1_score: 0.6443 - val_loss: 0.3813 - val_accuracy: 0.8348 - val_auc: 0.9121 - val_f1_score: 0.6477
# Epoch 32/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.4630 - accuracy: 0.8011 - auc: 0.8845 - f1_score: 0.6443 - val_loss: 0.3790 - val_accuracy: 0.8359 - val_auc: 0.9129 - val_f1_score: 0.6477
# Epoch 33/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.4654 - accuracy: 0.8015 - auc: 0.8833 - f1_score: 0.6443 - val_loss: 0.3788 - val_accuracy: 0.8361 - val_auc: 0.9134 - val_f1_score: 0.6477
# Epoch 34/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.4541 - accuracy: 0.8065 - auc: 0.8879 - f1_score: 0.6443 - val_loss: 0.3766 - val_accuracy: 0.8387 - val_auc: 0.9142 - val_f1_score: 0.6477
# Epoch 35/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.4535 - accuracy: 0.8067 - auc: 0.8886 - f1_score: 0.6443 - val_loss: 0.3758 - val_accuracy: 0.8371 - val_auc: 0.9148 - val_f1_score: 0.6477
# Epoch 36/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.4496 - accuracy: 0.8073 - auc: 0.8901 - f1_score: 0.6443 - val_loss: 0.3745 - val_accuracy: 0.8374 - val_auc: 0.9153 - val_f1_score: 0.6477
# Epoch 37/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.4463 - accuracy: 0.8096 - auc: 0.8918 - f1_score: 0.6443 - val_loss: 0.3737 - val_accuracy: 0.8384 - val_auc: 0.9159 - val_f1_score: 0.6477
# Epoch 38/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.4452 - accuracy: 0.8142 - auc: 0.8930 - f1_score: 0.6443 - val_loss: 0.3721 - val_accuracy: 0.8397 - val_auc: 0.9165 - val_f1_score: 0.6477
# Epoch 39/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.4468 - accuracy: 0.8104 - auc: 0.8917 - f1_score: 0.6443 - val_loss: 0.3715 - val_accuracy: 0.8400 - val_auc: 0.9170 - val_f1_score: 0.6477
# Epoch 40/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.4406 - accuracy: 0.8114 - auc: 0.8945 - f1_score: 0.6443 - val_loss: 0.3705 - val_accuracy: 0.8396 - val_auc: 0.9175 - val_f1_score: 0.6477
# Epoch 41/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.4340 - accuracy: 0.8138 - auc: 0.8962 - f1_score: 0.6443 - val_loss: 0.3698 - val_accuracy: 0.8408 - val_auc: 0.9179 - val_f1_score: 0.6477
# Epoch 42/100
# 938/938 [==============================] - 65s 69ms/step - loss: 0.4282 - accuracy: 0.8149 - auc: 0.8986 - f1_score: 0.6443 - val_loss: 0.3688 - val_accuracy: 0.8407 - val_auc: 0.9184 - val_f1_score: 0.6477
# Epoch 43/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.4301 - accuracy: 0.8172 - auc: 0.8988 - f1_score: 0.6443 - val_loss: 0.3682 - val_accuracy: 0.8413 - val_auc: 0.9188 - val_f1_score: 0.6477
# Epoch 44/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.4300 - accuracy: 0.8140 - auc: 0.8991 - f1_score: 0.6443 - val_loss: 0.3667 - val_accuracy: 0.8425 - val_auc: 0.9192 - val_f1_score: 0.6477
# Epoch 45/100
# 938/938 [==============================] - 65s 70ms/step - loss: 0.4247 - accuracy: 0.8182 - auc: 0.9011 - f1_score: 0.6443 - val_loss: 0.3674 - val_accuracy: 0.8424 - val_auc: 0.9194 - val_f1_score: 0.6477
# Epoch 46/100
# 938/938 [==============================] - 65s 69ms/step - loss: 0.4202 - accuracy: 0.8212 - auc: 0.9024 - f1_score: 0.6443 - val_loss: 0.3660 - val_accuracy: 0.8432 - val_auc: 0.9199 - val_f1_score: 0.6477
# Epoch 47/100
# 938/938 [==============================] - 66s 70ms/step - loss: 0.4213 - accuracy: 0.8189 - auc: 0.9025 - f1_score: 0.6443 - val_loss: 0.3657 - val_accuracy: 0.8443 - val_auc: 0.9203 - val_f1_score: 0.6477
# Epoch 47: early stopping

# %%
#Create a directory named saved models and then run this cell
model_name = "saved_models/Transfer_Learning_VGG16_" + classification_attribute + ".h5"
model_tl_2.save(model_name) ## Saving the model

# %% [markdown]
# ### Model Performance

# %%
curr_model = load_model("saved_models/Transfer_Learning_VGG16_Smiling.h5")

# %%
score = curr_model.evaluate(x_test, y_test, verbose=0)
# Out:
# 2023-06-02 05:01:28.822967: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.04GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-02 05:01:28.823045: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.04GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-02 05:01:28.865102: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.68GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-02 05:01:29.305820: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.55GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-02 05:01:29.305880: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.55GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-02 05:01:29.567023: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.34GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-02 05:01:29.582968: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.34GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.

# %%
print("Testing loss: ", score[0])
print("Testing accuracy: ", score[1])
print("Testing AUC: ", score[2])
print("Testing F1 score: ", score[3])
# Out:
# Testing loss:  0.36572062969207764
# Testing accuracy:  0.8443499803543091
# Testing AUC:  0.9202646613121033
# Testing F1 score:  [0.6476892]

# %% [markdown]
# #### Plot of training vs validation loss

# %%
plt.figure(figsize=[6,4])
plt.plot(history_tl_2.history['loss'],'r',linewidth=3.0)
plt.plot(history_tl_2.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Loss Curves')

# %% [markdown]
# ### Summary of hyperparameters
#
# The provided code snippet does not explicitly define any hyperparameters. However, I can provide a summary of the notable hyperparameters that can be inferred from the code:
#
# 1. The number of frozen layers:
#    This code snippet freezes the first 205 layers of the VGG16 base model by setting their `trainable` attribute to `False`. Freezing layers is a way to control the training of specific layers and can be considered as a form of hyperparameter in terms of network training. By minimising the number of trainable layers, we reduce the computational cost. However, the trade off is that the accuracy will be lesser.
#
# 2. Number of Dense layers:
#    The `Dense` layer added after the flattening operation has 1024 units. The choice of the number of units in this layer can be considered a hyperparameter. The activation function used in this layer is ReLU (Rectified Linear Unit).
#
# 3. Activation Function:
#     The ReLU (Rectified Linear Unit) activation function is a common choice for introducing non-linearity in neural networks. It helps the model learn complex relationships between the input and the output by mapping negative values to zero and leaving positive values unchanged. ReLU has been shown to work well in many deep learning architectures. It is also very easy to compute the gradients for ReLU functions.
#
# 4. Batch Normalization:
#     Batch normalization is a technique used to normalize the activations of a neural network layer, aiming to stabilize and speed up the training process. It helps mitigate the internal covariate shift by normalizing the mean and variance of each batch's input. Batch normalization can improve the model's ability to generalize and can also act as a regularizer, reducing the reliance on dropout or weight decay.
#
# 5. Dropout:
#     Dropout is a regularization technique that randomly sets a fraction of input units to zero during training. By doing so, dropout prevents units from relying too heavily on other specific units and encourages the network to learn more robust and generalizable representations. In this case, a dropout rate of 0.5 is applied, meaning that 50% of the units in the previous dense layer will be randomly set to zero during training.
#
# 6. Output Layer:
#     The output layer is a dense layer with the number of units equal to the number of classes in the dataset (102). The softmax activation function is used to compute probabilities for each class, allowing the model to provide a probability distribution over the classes and make predictions based on the highest probability.
