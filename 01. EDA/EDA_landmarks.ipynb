# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../00. Dataset/list_landmarks_align_celeba.csv')
data.head()
# Out:
#      image_id  lefteye_x  lefteye_y  righteye_x  righteye_y  nose_x  nose_y  \
# 0  000001.jpg         69        109         106         113      77     142
# 1  000002.jpg         69        110         107         112      81     135
# 2  000003.jpg         76        112         104         106     108     128
# 3  000004.jpg         72        113         108         108     101     138
# 4  000005.jpg         66        114         112         112      86     119
#
#    leftmouth_x  leftmouth_y  rightmouth_x  rightmouth_y
# 0           73          152           108           154
# 1           70          151           108           153
# 2           74          156            98           158
# 3           71          155           101           151
# 4           71          147           104           150

# %%
data.hist(bins=30, figsize=(20, 15))
plt.show()

# %% [markdown]
# It is seen that most of the features except for leftmouth_x and rightmouth_x are normally distributed. It would be of interest to normalize the features if it is to be used in modeling.
